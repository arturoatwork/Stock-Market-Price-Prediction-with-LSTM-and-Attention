# %%
# !pip install tensorflow -qqq
# !pip install keras -qqq
# !pip install yfinance -qqq

# %%
import tensorflow as tf
import keras
import yfinance as yf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Fetch any three of the stock data (AAL, TSLA, and MSFT) using yfinance
stock_data = yf.download('TSLA', start='2015-01-01', end='2025-01-01') #change the ticker symbol as needed

# Display the first few rows of the dataframe to make sure the data is loaded correctly
stock_data.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price           Close       High        Low       Open    Volume
# Ticker           TSLA       TSLA       TSLA       TSLA      TSLA
# Date
# 2015-01-02  14.620667  14.883333  14.217333  14.858000  71466000
# 2015-01-05  14.006000  14.433333  13.810667  14.303333  80527500
# 2015-01-06  14.085333  14.280000  13.614000  14.004000  93928500
# 2015-01-07  14.063333  14.318667  13.985333  14.223333  44526000
# 2015-01-08  14.041333  14.253333  14.000667  14.187333  51637500

# %%
# small data cleaning now

# Checking for missing values
stock_data.isnull().sum()

# Filling missing values, if any
stock_data.fillna(method='ffill', inplace=True)
# Out:
# /var/folders/tb/z5_y891551qgbzw64qqpwcqh0000gn/T/ipykernel_84390/2625841450.py:7: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   stock_data.fillna(method='ffill', inplace=True)

# %%
from sklearn.preprocessing import MinMaxScaler
# Scaling the data to a range of 0 to 1
scaler = MinMaxScaler(feature_range=(0,1))
stock_data_scaled = scaler.fit_transform(stock_data['Close'].values.reshape(-1,1))

# %%
# Preparing the data for LSTM
X = []
y = []

for i in range(60, len(stock_data_scaled)):
    X.append(stock_data_scaled[i-60:i, 0])
    y.append(stock_data_scaled[i, 0])

# %%
train_size = int(len(X) * 0.8)
test_size = len(X) - train_size

X_train, X_test = X[:train_size], X[train_size:]
y_train, y_test = y[:train_size], y[train_size:]

# %%
X_train, y_train = np.array(X_train), np.array(y_train)
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))

# %%
from keras.models import Sequential
from keras.layers import LSTM, Dense, Dropout, AdditiveAttention, Permute, Reshape, Multiply

model = Sequential()

# Adding LSTM layers with return_sequences=True
model.add(LSTM(units=50, return_sequences=True, input_shape=(X_train.shape[1], 1)))
model.add(LSTM(units=50, return_sequences=True))
# Out:
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
# Adding self-attention mechanism
# The attention mechanism
attention = AdditiveAttention(name='attention_weight')

# Define the input explicitly
input_layer = tf.keras.layers.Input(shape=(X_train.shape[1], 1))
x = LSTM(units=50, return_sequences=True)(input_layer)
x = LSTM(units=50, return_sequences=True)(x)

# Permute and reshape for compatibility
x = Permute((2, 1))(x)
x = Reshape((-1, X_train.shape[1]))(x)

# Apply attention
attention_result = attention([x, x])
x = Multiply()([x, attention_result])

# Return to original shape
x = Permute((2, 1))(x)
x = Reshape((-1, 50))(x)

# Adding a Flatten layer before the final Dense layer
x = tf.keras.layers.Flatten()(x)

# Final Dense layer
output_layer = Dense(1)(x)

# Create the model
model = tf.keras.models.Model(inputs=input_layer, outputs=output_layer)

# %%
from keras.layers import BatchNormalization, Dropout

# Adding Dropout and Batch Normalization
x = Dropout(0.2)(x)
x = BatchNormalization()(x)

# %%
model.compile(optimizer='adam', loss='mean_squared_error')

# %%
model.summary()
# Out:
# Model: "functional_5"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_3       │ (None, 60, 1)     │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm_6 (LSTM)       │ (None, 60, 50)    │     10,400 │ input_layer_3[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm_7 (LSTM)       │ (None, 60, 50)    │     20,200 │ lstm_6[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ permute_2 (Permute) │ (None, 50, 60)    │          0 │ lstm_7[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_2 (Reshape) │ (None, 50, 60)    │          0 │ permute_2[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ attention_weight    │ (None, 50, 60)    │         60 │ reshape_2[0][0],  │
# │ (AdditiveAttention) │                   │            │ reshape_2[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_1          │ (None, 50, 60)    │          0 │ reshape_2[0][0],  │
# │ (Multiply)          │                   │            │ attention_weight… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ permute_3 (Permute) │ (None, 60, 50)    │          0 │ multiply_1[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_3 (Reshape) │ (None, 60, 50)    │          0 │ permute_3[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten_1 (Flatten) │ (None, 3000)      │          0 │ reshape_3[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 1)         │      3,001 │ flatten_1[0][0]   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 33,661 (131.49 KB)
#  Trainable params: 33,661 (131.49 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Assuming X_train and y_train are already defined and preprocessed
history = model.fit(X_train, y_train, epochs=100, batch_size=25, validation_split=0.2)
# Out:
# Epoch 1/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - loss: 0.0141 - val_loss: 0.0142
# Epoch 2/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 0.0026 - val_loss: 0.0111
# Epoch 3/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 3s 47ms/step - loss: 8.9244e-04 - val_loss: 0.0104
# Epoch 4/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - loss: 6.7699e-04 - val_loss: 0.0082
# Epoch 5/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - loss: 7.0733e-04 - val_loss: 0.0159
# Epoch 6/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 3s 42ms/step - loss: 6.3327e-04 - val_loss: 0.0090
# Epoch 7/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - loss: 5.0984e-04 - val_loss: 0.0107
# Epoch 8/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 5.2875e-04 - val_loss: 0.0064
# Epoch 9/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 5.6037e-04 - val_loss: 0.0070
# Epoch 10/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 3s 49ms/step - loss: 3.6585e-04 - val_loss: 0.0211
# Epoch 11/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 62ms/step - loss: 9.2012e-04 - val_loss: 0.0061
# Epoch 12/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 3s 49ms/step - loss: 4.9193e-04 - val_loss: 0.0099
# Epoch 13/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 3.7891e-04 - val_loss: 0.0052
# Epoch 14/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: 3.9808e-04 - val_loss: 0.0077
# Epoch 15/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 3.4092e-04 - val_loss: 0.0053
# Epoch 16/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 3.1555e-04 - val_loss: 0.0038
# Epoch 17/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 3.0228e-04 - val_loss: 0.0117
# Epoch 18/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - loss: 6.1688e-04 - val_loss: 0.0087
# Epoch 19/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 3.6226e-04 - val_loss: 0.0035
# Epoch 20/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 2.6306e-04 - val_loss: 0.0038
# Epoch 21/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 2.1073e-04 - val_loss: 0.0087
# Epoch 22/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 2.2851e-04 - val_loss: 0.0025
# Epoch 23/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 2.1724e-04 - val_loss: 0.0035
# Epoch 24/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 2.1642e-04 - val_loss: 0.0021
# Epoch 25/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 2.2851e-04 - val_loss: 0.0051
# Epoch 26/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - loss: 2.6236e-04 - val_loss: 0.0075
# Epoch 27/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 1.9789e-04 - val_loss: 0.0023
# Epoch 28/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 1.7671e-04 - val_loss: 0.0054
# Epoch 29/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - loss: 2.2983e-04 - val_loss: 0.0052
# Epoch 30/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 7s 100ms/step - loss: 2.0791e-04 - val_loss: 0.0023
# Epoch 31/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 1.8860e-04 - val_loss: 0.0026
# Epoch 32/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - loss: 2.0040e-04 - val_loss: 0.0058
# Epoch 33/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - loss: 4.6810e-04 - val_loss: 0.0043
# Epoch 34/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 1.8783e-04 - val_loss: 0.0022
# Epoch 35/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 3s 45ms/step - loss: 1.6869e-04 - val_loss: 0.0033
# Epoch 36/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - loss: 2.0171e-04 - val_loss: 0.0017
# Epoch 37/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - loss: 2.2996e-04 - val_loss: 0.0027
# Epoch 38/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 2.4820e-04 - val_loss: 0.0017
# Epoch 39/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 1.8851e-04 - val_loss: 0.0016
# Epoch 40/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 1.4397e-04 - val_loss: 0.0022
# Epoch 41/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 1.6575e-04 - val_loss: 0.0050
# Epoch 42/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 2.2156e-04 - val_loss: 0.0017
# Epoch 43/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 1.5869e-04 - val_loss: 0.0026
# Epoch 44/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 2.1863e-04 - val_loss: 0.0017
# Epoch 45/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 1.7432e-04 - val_loss: 0.0022
# Epoch 46/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 1.3880e-04 - val_loss: 0.0032
# Epoch 47/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 1.9091e-04 - val_loss: 0.0016
# Epoch 48/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - loss: 1.1212e-04 - val_loss: 0.0014
# Epoch 49/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 60ms/step - loss: 1.2401e-04 - val_loss: 0.0014
# Epoch 50/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - loss: 1.4553e-04 - val_loss: 0.0026
# Epoch 51/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 2.0995e-04 - val_loss: 0.0044
# Epoch 52/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - loss: 2.2301e-04 - val_loss: 0.0014
# Epoch 53/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 3s 50ms/step - loss: 1.3304e-04 - val_loss: 0.0028
# Epoch 54/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - loss: 1.3876e-04 - val_loss: 0.0014
# Epoch 55/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 1.2609e-04 - val_loss: 0.0012
# Epoch 56/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 1.3521e-04 - val_loss: 0.0013
# Epoch 57/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 1.9471e-04 - val_loss: 0.0015
# Epoch 58/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 1.2032e-04 - val_loss: 0.0020
# Epoch 59/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - loss: 1.0307e-04 - val_loss: 0.0017
# Epoch 60/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 1.1778e-04 - val_loss: 0.0014
# Epoch 61/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 1.0910e-04 - val_loss: 0.0012
# Epoch 62/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 7.7584e-05 - val_loss: 0.0015
# Epoch 63/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 8.4289e-05 - val_loss: 0.0015
# Epoch 64/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 1.4713e-04 - val_loss: 0.0015
# Epoch 65/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 1.0104e-04 - val_loss: 0.0012
# Epoch 66/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 8.3538e-05 - val_loss: 0.0013
# Epoch 67/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 1.5401e-04 - val_loss: 0.0065
# Epoch 68/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 1.6152e-04 - val_loss: 0.0027
# Epoch 69/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 9.2711e-05 - val_loss: 0.0013
# Epoch 70/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 1.1882e-04 - val_loss: 0.0013
# Epoch 71/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 1.1901e-04 - val_loss: 0.0013
# Epoch 72/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 1.1776e-04 - val_loss: 0.0011
# Epoch 73/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 1.2682e-04 - val_loss: 0.0032
# Epoch 74/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 3.4586e-04 - val_loss: 0.0024
# Epoch 75/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 9.8137e-05 - val_loss: 0.0016
# Epoch 76/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 1.1283e-04 - val_loss: 0.0014
# Epoch 77/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 1.0034e-04 - val_loss: 0.0013
# Epoch 78/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 1.0096e-04 - val_loss: 0.0027
# Epoch 79/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 1.2898e-04 - val_loss: 0.0013
# Epoch 80/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 7.3351e-05 - val_loss: 0.0035
# Epoch 81/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 1.5760e-04 - val_loss: 0.0044
# Epoch 82/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 1.7246e-04 - val_loss: 0.0020
# Epoch 83/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 1.1326e-04 - val_loss: 0.0027
# Epoch 84/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 9.7246e-05 - val_loss: 0.0013
# Epoch 85/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 7.6131e-05 - val_loss: 0.0019
# Epoch 86/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 8.2857e-05 - val_loss: 0.0017
# Epoch 87/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 1.0888e-04 - val_loss: 0.0013
# Epoch 88/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 8.0430e-05 - val_loss: 0.0013
# Epoch 89/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 9.9424e-05 - val_loss: 0.0011
# Epoch 90/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 8.7417e-05 - val_loss: 0.0034
# Epoch 91/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 8.6845e-05 - val_loss: 0.0019
# Epoch 92/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 1.1523e-04 - val_loss: 0.0019
# Epoch 93/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 6.0230e-05 - val_loss: 0.0014
# Epoch 94/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 7.1255e-05 - val_loss: 0.0012
# Epoch 95/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 7.0775e-05 - val_loss: 0.0012
# Epoch 96/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - loss: 9.5161e-05 - val_loss: 0.0014
# Epoch 97/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 1.0638e-04 - val_loss: 0.0013
# Epoch 98/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 7.1856e-05 - val_loss: 0.0014
# Epoch 99/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 3s 45ms/step - loss: 8.8987e-05 - val_loss: 0.0012
# Epoch 100/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - loss: 8.6383e-05 - val_loss: 0.0015

# %%
from keras.callbacks import EarlyStopping

early_stopping = EarlyStopping(monitor='val_loss', patience=10)
history = model.fit(X_train, y_train, epochs=100, batch_size=25, validation_split=0.2, callbacks=[early_stopping])
# Out:
# Epoch 1/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 7.7128e-05 - val_loss: 0.0020
# Epoch 2/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 6.8516e-05 - val_loss: 0.0015
# Epoch 3/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - loss: 8.3346e-05 - val_loss: 0.0011
# Epoch 4/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 7.1390e-05 - val_loss: 0.0021
# Epoch 5/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 9.1126e-05 - val_loss: 0.0011
# Epoch 6/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 1.2205e-04 - val_loss: 0.0014
# Epoch 7/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 60ms/step - loss: 8.4557e-05 - val_loss: 0.0019
# Epoch 8/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 1.3137e-04 - val_loss: 0.0013
# Epoch 9/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 1.0177e-04 - val_loss: 0.0012
# Epoch 10/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 9.6110e-05 - val_loss: 0.0011
# Epoch 11/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 7.3832e-05 - val_loss: 0.0015
# Epoch 12/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 7.3695e-05 - val_loss: 0.0021
# Epoch 13/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 5.9422e-05 - val_loss: 0.0012
# Epoch 14/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 9.0474e-05 - val_loss: 0.0033
# Epoch 15/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 7.5704e-05 - val_loss: 0.0026
# Epoch 16/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 6.1687e-05 - val_loss: 0.0023
# Epoch 17/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 1.3659e-04 - val_loss: 0.0014
# Epoch 18/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 7.1132e-05 - val_loss: 0.0014
# Epoch 19/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 5.7164e-05 - val_loss: 0.0010
# Epoch 20/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 7.9295e-05 - val_loss: 0.0010
# Epoch 21/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 6.9825e-05 - val_loss: 0.0026
# Epoch 22/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 9.7531e-05 - val_loss: 0.0016
# Epoch 23/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 6.7931e-05 - val_loss: 0.0023
# Epoch 24/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 9.7978e-05 - val_loss: 0.0036
# Epoch 25/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 1.1603e-04 - val_loss: 0.0021
# Epoch 26/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 1.0502e-04 - val_loss: 0.0011
# Epoch 27/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 7.9966e-05 - val_loss: 0.0020
# Epoch 28/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 8.8204e-05 - val_loss: 0.0035
# Epoch 29/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 8.5769e-05 - val_loss: 0.0014
# Epoch 30/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 5.8517e-05 - val_loss: 0.0011

# %%
# Convert X_test and y_test to Numpy arrays if they are not already
X_test = np.array(X_test)
y_test = np.array(y_test)

# Ensure X_test is reshaped similarly to how X_train was reshaped
# This depends on how you preprocessed the training data
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))

# Now evaluate the model on the test data
test_loss = model.evaluate(X_test, y_test)
print("Test Loss: ", test_loss)
# Out:
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 4.1592e-04
# Test Loss:  0.0005081575363874435

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error

# Making predictions
y_pred = model.predict(X_test)

# Calculating MAE and RMSE
mae = mean_absolute_error(y_test, y_pred)
rmse = np.sqrt(mean_squared_error(y_test, y_pred))

print("Mean Absolute Error: ", mae)
print("Root Mean Square Error: ", rmse)
# Out:
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step
# Mean Absolute Error:  0.017062387274784024
# Root Mean Square Error:  0.022542348941961284

# %%
import yfinance as yf
import numpy as np
from sklearn.preprocessing import MinMaxScaler

# Fetching the latest 60 days of stock stock data
data = yf.download('TSLA', period='60d', interval='1d') #change the ticker symbol as needed

# Selecting the 'Close' price and converting to numpy array
closing_prices = data['Close'].values

# Scaling the data
scaler = MinMaxScaler(feature_range=(0,1))
scaled_data = scaler.fit_transform(closing_prices.reshape(-1,1))

# Since we need the last 60 days to predict the next day, we reshape the data accordingly
X_latest = np.array([scaled_data[-60:].reshape(60)])

# Reshaping the data for the model (adding batch dimension)
X_latest = np.reshape(X_latest, (X_latest.shape[0], X_latest.shape[1], 1))

# Making predictions for the next 4 candles
predicted_stock_price = model.predict(X_latest)
predicted_stock_price = scaler.inverse_transform(predicted_stock_price)

print("Predicted Stock Prices for the next 4 days: ", predicted_stock_price)
# Out:
# [*********************100%***********************]  1 of 1 completed
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# Predicted Stock Prices for the next 4 days:  [[249.76018]]

# %%
import yfinance as yf
import numpy as np
from sklearn.preprocessing import MinMaxScaler

# Fetch the latest 60 days of desired stock data
data = yf.download('TSLA', period='60d', interval='1d') #change the ticker symbol as needed

# Select 'Close' price and scale it
closing_prices = data['Close'].values.reshape(-1, 1)
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(closing_prices)

# Predict the next 4 days iteratively
predicted_prices = []
current_batch = scaled_data[-60:].reshape(1, 60, 1)  # Most recent 60 days

for i in range(4):  # Predicting 4 days
    # Get the prediction (next day)
    next_prediction = model.predict(current_batch)
    
    # Reshape the prediction to fit the batch dimension
    next_prediction_reshaped = next_prediction.reshape(1, 1, 1)
    
    # Append the prediction to the batch used for predicting
    current_batch = np.append(current_batch[:, 1:, :], next_prediction_reshaped, axis=1)
    
    # Inverse transform the prediction to the original price scale
    predicted_prices.append(scaler.inverse_transform(next_prediction)[0, 0])

print("Predicted Stock Prices for the next 4 days: ", predicted_prices)
# Out:
# [*********************100%***********************]  1 of 1 completed
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Predicted Stock Prices for the next 4 days:  [np.float32(249.76018), np.float32(238.69205), np.float32(234.13124), np.float32(237.18866)]

# %%
# !pip install mplfinance -qqq
import pandas as pd
import mplfinance as mpf
import matplotlib.dates as mpl_dates
import matplotlib.pyplot as plt

# Assuming 'data' is your DataFrame with the fetched stock data
# Flatten multi-index columns if necessary
if isinstance(data.columns, pd.MultiIndex):
	data.columns = [col[0] for col in data.columns]

# Ensure all required columns are of type float or int
data = data.astype({'Open': 'float', 'High': 'float', 'Low': 'float', 'Close': 'float', 'Volume': 'int'})

# Creating a list of dates for the predictions
last_date = data.index[-1]
next_day = last_date + pd.Timedelta(days=1)
prediction_dates = pd.date_range(start=next_day, periods=4)

# Assuming 'predicted_prices' is your list of predicted prices for the next 4 days
predictions_df = pd.DataFrame(index=prediction_dates, data=predicted_prices, columns=['Close'])

# Plotting the actual data with mplfinance
mpf.plot(data, type='candle', style='charles', volume=True)

# Overlaying the predicted data
plt.figure(figsize=(10,6))
plt.plot(predictions_df.index, predictions_df['Close'], linestyle='dashed', marker='o', color='red')

plt.title(" 'TSLA' Stock Price with Predicted Next 4 Days ") #change the ticker symbol as needed
plt.show()

# %%
import pandas as pd
import mplfinance as mpf
import matplotlib.dates as mpl_dates
import matplotlib.pyplot as plt

# Fetch the latest 60 days of stock data
data = yf.download('TSLA', period='64d', interval='1d') # Fetch 64 days to display last 60 days in the chart # change the ticker symbol as needed

# Select 'Close' price and scale it
closing_prices = data['Close'].values.reshape(-1, 1)
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(closing_prices)

# Predict the next 4 days 
predicted_prices = []
current_batch = scaled_data[-60:].reshape(1, 60, 1)  # Most recent 60 days

for i in range(4):  # Predicting 4 days
    next_prediction = model.predict(current_batch)
    next_prediction_reshaped = next_prediction.reshape(1, 1, 1)
    current_batch = np.append(current_batch[:, 1:, :], next_prediction_reshaped, axis=1)
    predicted_prices.append(scaler.inverse_transform(next_prediction)[0, 0])

# Creating a list of dates for the predictions
last_date = data.index[-1]
next_day = last_date + pd.Timedelta(days=1)
prediction_dates = pd.date_range(start=next_day, periods=4)

# Adding preds to the df
predicted_data = pd.DataFrame(index=prediction_dates, data=predicted_prices, columns=['Close'])

# Combining actual and predicted data
combined_data = pd.concat([data['Close'], predicted_data['Close']])
combined_data = combined_data[-64:] # Last 60 days of actual data + 4 days of predictions

# Plotting the real data
plt.figure(figsize=(10,6))
plt.plot(data.index[-60:], data['Close'][-60:], linestyle='-', marker='o', color='blue', label='Actual Data')

# Plotting the predicted data
plt.plot(prediction_dates, predicted_prices, linestyle='-', marker='o', color='red', label='Predicted Data')

plt.title(" 'TSLA' Stock Price: Last 60 Days and Next 4 Days Predicted") # change the ticker symbol as needed
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.show()
# Out:
# [*********************100%***********************]  1 of 1 completed
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
